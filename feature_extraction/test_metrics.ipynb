# %%
import torch
import numpy as np
import os

# %%
real_folder = "/scratch/toskov/data/geom_align_outputs/"
real_files = os.listdir(real_folder)

gen_folder = "/scratch/toskov/data/geom_align_outputs_gen/"
gen_files = os.listdir(gen_folder)

# %%
real_means = []
n_missing = 0
n_good = 0
real_mean_list = []
real_max_list = []
real_median_list = []
for real in real_files:
    folder = os.path.join(real_folder, real)
    if not os.path.isdir(folder):
        continue
    
    metrics_file = os.path.join(folder, "metrics.pth")
    if not os.path.exists(metrics_file):
        n_missing += 1
        continue
    
    metrics = torch.load(metrics_file)
    n_good += 1
    
    # Has n_frames elements, each of which has (up to) window_size elements.
    # Average over the windows and then over the frames
    
    #do this for a bunch of metrics
    
    mean = np.mean([np.mean([x["mean"] for x in frame]) for frame in metrics])
    real_mean_list.append(mean)
    
    max_value = np.max([np.max([x["mean"] for x in frame]) for frame in metrics])
    real_max_list.append(max_value)
    
    # median = np.median([np.median([x["mean"] for x in frame]) for frame in metrics])
    # real_median_list.append(median)
    


print(f"Number of missing files: {n_missing}")
print(f"Number of good files: {n_good}")
print(real_mean_list)
# Out:
# Number of missing files: 14
# Number of good files: 129
# [np.float64(0.9048726468816497), np.float64(0.8526694178696442), np.float64(2.055731861392361), np.float64(0.08875683758465945), np.float64(0.35555243540899834), np.float64(0.04497365565961874), np.float64(1.0537949366051271), np.float64(1.144137244005894), np.float64(1.3367283940653214), np.float64(0.12331606157444677), np.float64(0.4409334455553562), np.float64(0.1512363777182931), np.float64(0.2822904967436324), np.float64(0.4190189872233586), np.float64(0.0844688663064677), np.float64(0.05822476738932342), np.float64(0.07895146779441767), np.float64(0.19539746219495166), np.float64(0.2960320515778847), np.float64(1.1436283938945706), np.float64(0.890599522991366), np.float64(0.22216072475903914), np.float64(0.42616632154094664), np.float64(0.23571805069024243), np.float64(0.3312995207638464), np.float64(1.0125875407243663), np.float64(0.065137717908337), np.float64(0.21842312028013694), np.float64(0.02429989709988395), np.float64(0.09663345272446597), np.float64(0.14726605084958994), np.float64(0.06263113765134698), np.float64(0.18755866823961495), np.float64(0.09082050398691188), np.float64(0.08802526224948785), np.float64(0.03406874918319257), np.float64(0.03399713271529781), np.float64(0.0689417691826159), np.float64(0.10376662535872036), np.float64(0.07557311280376716), np.float64(0.048386015120556965), np.float64(0.3431389263826819), np.float64(0.09504616866867918), np.float64(0.12582247621299117), np.float64(0.18410628805473697), np.float64(0.1590843801541499), np.float64(0.1013579988481318), np.float64(0.02705832317183739), np.float64(0.30355731248424633), np.float64(0.4322924905604431), np.float64(0.24580265721028086), np.float64(0.041820764685934625), np.float64(0.08852332853539256), np.float64(0.09355360574284677), np.float64(0.04824505168656456), np.float64(0.23759700440507778), np.float64(0.049549069471019856), np.float64(0.43617382711169145), np.float64(0.11399705657785704), np.float64(0.07019520624067693), np.float64(0.041456133988617), np.float64(0.02197414574115358), np.float64(0.1349093459629751), np.float64(0.07434003665095047), np.float64(0.05206944708354603), np.float64(0.22031705968003276), np.float64(0.05265744343539813), np.float64(0.9076150287641085), np.float64(0.06810544253311167), np.float64(0.024910111592008656), np.float64(0.06442473164850028), np.float64(0.06931191958799729), np.float64(0.25620684661695015), np.float64(0.08385362676902303), np.float64(0.06587815237880998), np.float64(0.08993861992761515), np.float64(1.0636455808949825), np.float64(0.10669735683579742), np.float64(0.07498505336453225), np.float64(0.028517254162166356), np.float64(0.024872628031704425), np.float64(0.2534450776298611), np.float64(0.05410337877856414), np.float64(0.11526030245459296), np.float64(0.27662339291858795), np.float64(nan), np.float64(0.10604746986630545), np.float64(0.06054086815189988), np.float64(0.03983486853179767), np.float64(0.07977695912979633), np.float64(0.05138243482845796), np.float64(0.0637507947837297), np.float64(0.12299042805726897), np.float64(0.0655737041487973), np.float64(0.19087581085282954), np.float64(0.1123066162644919), np.float64(0.04746628134900527), np.float64(0.11463824557188076), np.float64(0.05503249007074489), np.float64(0.08249715218968932), np.float64(0.0850365121160474), np.float64(0.043423012147246906), np.float64(0.08260609069054875), np.float64(0.13990516467705189), np.float64(0.05808912149277451), np.float64(0.09433994950540717), np.float64(0.14913459570117782), np.float64(0.10873881190126265), np.float64(0.2674339608990111), np.float64(0.1715976047480315), np.float64(0.07771211301866304), np.float64(0.09455968861719698), np.float64(0.18093183984098526), np.float64(0.34815119795485194), np.float64(0.34687075643397547), np.float64(0.05069262338879891), np.float64(0.06718482357169957), np.float64(0.11310993401202897), np.float64(0.0643024379292286), np.float64(0.1075572329335053), np.float64(0.06897400775425715), np.float64(0.057297917101998254), np.float64(0.26619625 ...
# /tmp/ipykernel_16168/3460152102.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   metrics = torch.load(metrics_file)

# %%
gen_means = []
n_missing = 0
n_good = 0
gen_mean_list = []
gen_max_list = []
gen_median_list = []
for gen in gen_files:
    folder = os.path.join(gen_folder, gen)
    if not os.path.isdir(folder):
        continue
    
    metrics_file = os.path.join(folder, "metrics.pth")
    if not os.path.exists(metrics_file):
        n_missing += 1
        continue
    
    metrics = torch.load(metrics_file)
    n_good += 1
    
    # Has n_frames elements, each of which has (up to) window_size elements.
    # Average over the windows and then over the frames
    
    #do this for a bunch of metrics
    
    mean = np.mean([np.mean([x["mean"] for x in frame]) for frame in metrics])
    gen_mean_list.append(mean)
    
    # max_value = np.max([np.max([x["mean"] for x in frame]) for frame in metrics])
    # gen_max_list.append(max_value)
    
    # median = np.median([np.median([x["mean"] for x in frame]) for frame in metrics])
    # gen_median_list.append(median)
    


print(f"Number of missing files: {n_missing}")
print(f"Number of good files: {n_good}")
print(gen_mean_list)
# Out:
# Number of missing files: 1
# Number of good files: 30
# [np.float64(0.23671404699007445), np.float64(0.6983228964735606), np.float64(0.7315077558634886), np.float64(0.5356707096036212), np.float64(0.13441275207173978), np.float64(0.4361810664385497), np.float64(0.3511592495183263), np.float64(0.7632340950505015), np.float64(1.2684849651369525), np.float64(0.6596114700524308), np.float64(0.8408430232721806), np.float64(0.9916066895031844), np.float64(0.34580189492881697), np.float64(0.294720095776689), np.float64(0.5852356267405961), np.float64(0.5960914721475442), np.float64(0.3765508946815578), np.float64(0.5868367009220672), np.float64(0.8899550953792258), np.float64(0.8413809922995847), np.float64(0.60119778392859), np.float64(1.0407943028049633), np.float64(0.4321067470646764), np.float64(0.9166481579381563), np.float64(0.4555363105118419), np.float64(0.337012987198919), np.float64(0.39041220407075083), np.float64(0.31375954082410584), np.float64(0.5062398491424797), np.float64(0.4085768795353109)]
# /tmp/ipykernel_16168/2774953534.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   metrics = torch.load(metrics_file)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# start with means

# Combine data
X = np.array(real_mean_list + gen_mean_list)
y = np.concatenate([np.zeros_like(real_mean_list), np.ones_like(gen_mean_list)])

mask = np.isnan(X)

X = X[~mask]
y = y[~mask]
# Ensure that the lengths of X and y match
if len(X) != len(y):
    raise ValueError("Length of X and y do not match after filtering NaNs.")

# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y, X)  # Use values as scores
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Chance level')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
# plt.show()
plt.savefig("roc_curve_means.png")

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

# Compute PR curve
precision, recall, thresholds = precision_recall_curve(y, X)
ap_score = average_precision_score(y, X)

# Compute F1 scores (excluding the last point, which is for threshold=None)
f1_scores = 2 * precision[:-1] * recall[:-1] / (precision[:-1] + recall[:-1] + 1e-8)
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_precision = precision[best_idx]
best_recall = recall[best_idx]
best_f1 = f1_scores[best_idx]

# Plot PR curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label=f'PR curve (AP = {ap_score:.2f})')
plt.scatter(best_recall, best_precision, color='red', label=f'Best F1 = {best_f1:.2f}\nThreshold = {best_threshold:.2f}', zorder=5)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve with Best Threshold')
plt.legend(loc="upper right")
plt.grid(True)
# plt.show()
plt.savefig("pr_curve.png")

# %%
thresholds
# Out:
# array([0.02197415, 0.0242999 , 0.02487263, 0.02491011, 0.02705832,
#        0.02851725, 0.03031755, 0.03399713, 0.03406875, 0.03983487,
#        0.04145613, 0.04182076, 0.04342301, 0.04497366, 0.04510877,
#        0.04746628, 0.04824505, 0.04838602, 0.04954907, 0.05069262,
#        0.05138243, 0.05160052, 0.05206945, 0.05265744, 0.05410338,
#        0.05503249, 0.05729792, 0.05808912, 0.05822477, 0.06054087,
#        0.06263114, 0.06375079, 0.06430244, 0.06442473, 0.06513772,
#        0.0655737 , 0.06587815, 0.06718482, 0.06776249, 0.06810544,
#        0.06894177, 0.06897401, 0.06931192, 0.07019521, 0.07181856,
#        0.07434004, 0.07498505, 0.07557311, 0.07771211, 0.07895147,
#        0.07977696, 0.08249715, 0.08260609, 0.08385363, 0.08446887,
#        0.08503651, 0.08802526, 0.08844246, 0.08852333, 0.08875684,
#        0.08993862, 0.0908205 , 0.09355361, 0.09433995, 0.09455969,
#        0.09504617, 0.09663345, 0.101358  , 0.10376663, 0.10604747,
#        0.10669736, 0.10755723, 0.10873881, 0.11230662, 0.11310993,
#        0.11399706, 0.11463825, 0.1152603 , 0.12299043, 0.12331606,
#        0.12582248, 0.13441275, 0.13490935, 0.13990516, 0.14726605,
#        0.1491346 , 0.15123638, 0.15908438, 0.1715976 , 0.18093184,
#        0.18410629, 0.18755867, 0.19087581, 0.19539746, 0.21842312,
#        0.22031706, 0.22216072, 0.23571805, 0.23671405, 0.237597  ,
#        0.24580266, 0.25344508, 0.25620685, 0.26619626, 0.26743396,
#        0.27662339, 0.2822905 , 0.2947201 , 0.29603205, 0.30355731,
#        0.31375954, 0.33129952, 0.33701299, 0.34313893, 0.34580189,
#        0.34687076, 0.3481512 , 0.35115925, 0.35555244, 0.37655089,
#        0.3904122 , 0.40857688, 0.41901899, 0.42616632, 0.43210675,
#        0.43229249, 0.43617383, 0.43618107, 0.44093345, 0.45553631,
#        0.50623985, 0.53567071, 0.58523563, 0.5868367 , 0.59609147,
#        0.60119778, 0.65961147, 0.6983229 , 0.73150776, 0.7632341 ,
#        0.84084302, 0.84138099, 0.85266942, 0.8899551 , 0.89059952,
#        0.90487265, 0.90761503, 0.91664816, 0.99160669, 1.01258754,
#        1.0407943 , 1.05379494, 1.06364558, 1.14362839, 1.14413724,
#        1.26848497, 1.33672839, 2.05573186])
